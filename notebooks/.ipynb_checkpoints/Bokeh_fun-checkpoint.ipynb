# %%
from collections import OrderedDict
from math import log, sqrt

import numpy as np
import pandas as pd
from six.moves import cStringIO as StringIO

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="24fe39a3-ef03-4596-bd52-629419cc3d61">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, show

# %%
data = """
bacteria,                        penicillin, streptomycin, neomycin, gram
Mycobacterium tuberculosis,      800,        5,            2,        negative
Klebsiella pneumoniae,           850,        1.2,          1,        negative
Brucella antracis,               0.001,      0.01,         0.007,    positive
Streptococcus fecalis,           1,          1,            0.1,      positive
Staphylococcus aureus,           0.03,       0.03,         0.001,    positive
"""

# %%
drug_color = OrderedDict([
    ("Penicillin",   "#0d3362"),
    ("Streptomycin", "#c64737"),
    ("Neomycin",     "black"  ),
])

gram_color = {
    "positive" : "#aeaeb8",
    "negative" : "#e69584",
}

df = pd.read_csv(StringIO(data),
                 skiprows=1,
                 skipinitialspace=True,
                 engine='python')
print(df)
# Out:
#                      bacteria  penicillin  streptomycin  neomycin      gram
# 0  Mycobacterium tuberculosis     800.000          5.00     2.000  negative
# 1       Klebsiella pneumoniae     850.000          1.20     1.000  negative
# 2           Brucella antracis       0.001          0.01     0.007  positive
# 3       Streptococcus fecalis       1.000          1.00     0.100  positive
# 4       Staphylococcus aureus       0.030          0.03     0.001  positive

# %%
width = 800
height = 800

p = figure(plot_width=width, plot_height=height, title="",
    x_axis_type=None, y_axis_type=None,
    x_range=(-420, 420), y_range=(-420, 420),
    min_border=0, outline_line_color="black",
    background_fill_color="#f0e1d2")

inner_radius = 90
outer_radius = 300-10
big_angle = 2.0 * np.pi / (len(df) + 1)
small_angle = big_angle / 7 # why divide by 7?

angles = np.pi/2 - big_angle/2 - df.index.to_series()*big_angle
colors = [gram_color[gram] for gram in df.gram]
print(-big_angle+angles)
print(angles)

ii = 0
start_ang = np.pi/2 - big_angle*3./2 - ii*big_angle +5*small_angle
end_ang = np.pi/2 - big_angle/2 - ii*big_angle + 6*small_angle
print(start_ang, end_ang)
p.annular_wedge(0,0,inner_radius, outer_radius, start_ang, end_ang)

# p.annular_wedge(
#     0, 0, inner_radius, outer_radius, -big_angle+angles, angles, color=colors,
# )


# minr = sqrt(log(.001 * 1E4))
# maxr = sqrt(log(1000 * 1E4))
# a = (outer_radius - inner_radius) / (minr - maxr)
# b = inner_radius - a * maxr
# def rad(mic):
#     return a * np.sqrt(np.log(mic * 1E4)) + b


# # small wedges
# p.annular_wedge(0, 0, inner_radius, rad(df.penicillin),
#                 -big_angle+angles+5*small_angle, -big_angle+angles+6*small_angle,
#                 color=drug_color['Penicillin'])
# p.annular_wedge(0, 0, inner_radius, rad(df.streptomycin),
#                 -big_angle+angles+3*small_angle, -big_angle+angles+4*small_angle,
#                 color=drug_color['Streptomycin'])
# p.annular_wedge(0, 0, inner_radius, rad(df.neomycin),
#                 -big_angle+angles+1*small_angle, -big_angle+angles+2*small_angle,
#                 color=drug_color['Neomycin'])


show(p)
# Out:
# 0    2.220446e-16
# 1   -1.047198e+00
# 2   -2.094395e+00
# 3   -3.141593e+00
# 4   -4.188790e+00
# dtype: float64
# 0    1.047198e+00
# 1    2.220446e-16
# 2   -1.047198e+00
# 3   -2.094395e+00
# 4   -3.141593e+00
# dtype: float64
# (0.7479982508547125, 1.944795452222253)
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e923e62f-5b5d-47e1-be45-f1b3889db8ef"></div>
# </div>
